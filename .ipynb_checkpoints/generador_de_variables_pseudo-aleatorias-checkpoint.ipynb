# %% [markdown]
# # Generador de l'ecuyer

# %% [markdown]
# Imagina que quieres crear una lista de números aleatorios, pero no tienes ningún dado o moneda para tirar y obtener un resultado aleatorio. En su lugar, puedes usar un programa de ordenador que genera números "pseudoaleatorios". Estos números no son realmente aleatorios, pero pueden parecerlo si se hacen correctamente.
#
# El generador de L'Ecuyer es una manera de generar números pseudoaleatorios. Utiliza dos fórmulas matemáticas para producir una lista de números que parecen aleatorios. Las fórmulas son como un "juego matemático" que usa dos números especiales llamados "semillas" para crear una serie de números. Cada número generado se calcula a partir del número anterior.
#
# Los generadores lineales congruentes son un tipo de fórmula que se utiliza en el generador de L'Ecuyer. Una fórmula lineal congruente es como un "truco matemático" que toma un número inicial (la semilla), lo multiplica por otro número (a), le suma otro número (c) y toma el resultado módulo de un tercer número (m). La fórmula se escribe así:
#
# Xn+1 = (aXn + c) % m
#
# En esta fórmula, Xn es el número anterior de la serie, Xn+1 es el siguiente número, a, c y m son números especiales que se eligen cuidadosamente para obtener una serie de números pseudoaleatorios que parezcan aleatorios.
#
# El generador de L'Ecuyer utiliza dos fórmulas lineales congruentes juntas para generar una serie de números. Cada fórmula tiene su propia semilla, a, c y m. Cuando las dos fórmulas se combinan, se crea una secuencia de números que parecen aleatorios.
#
# El generador de L'Ecuyer es una herramienta matemática que usa dos fórmulas llamadas generadores lineales congruentes para crear una serie de números pseudoaleatorios. Cada fórmula tiene su propia semilla, que es como un número de inicio. Cuando se combinan, las fórmulas crean una serie de números que parecen aleatorios.x

# %% [markdown]
# Generador de L'Ecuyer
#
# El generador de L'Ecuyer utiliza dos GLC con parámetros cuidadosamente elegidos para garantizar que la secuencia resultante tenga propiedades estadísticas deseables, como una distribución uniforme y una correlación baja entre los números generados. Además, el generador de L'Ecuyer tiene un periodo largo, lo que significa que puede generar una gran cantidad de números pseudoaleatorios antes de que se repita la secuencia.
#
# La fórmula para el generador de L'Ecuyer es la siguiente:
#
# X[n+1] = (a * X[n] + c) % m
#
# Y[n+1] = (a * Y[n] + c) % m
#
# Z[n+1] = (X[n+1] - Y[n+1]) % m
#
# En esta fórmula, $X_n$ y $Y_n$ son los números anteriores de las dos series de GLC, $a_1$, $a_2$, $c_1$, $c_2$, $m_1$ y $m_2$ son los parámetros cuidadosamente elegidos y $Z_{n+1}$ es el número pseudoaleatorio resultante. La elección de los parámetros se realiza de manera que las secuencias de números generados tengan una buena calidad estadística.
#
# Conclusión
# En resumen, el generador de L'Ecuyer es un método para generar números pseudoaleatorios mediante la combinación de dos generadores lineales congruentes, que se basa en la elección cuidadosa de parámetros para garantizar propiedades estadísticas deseables. El generador de L'Ecuyer se utiliza en aplicaciones de simulación y optimización donde se requiere una secuencia de números pseudoaleatorios que parezcan aleatorios.

# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import sympy as sp #para las formulas
import numpy as np
# !pip install scipy
from scipy.stats import chi2
# Out:
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (1.9.1)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in c:\users\user\anaconda3\lib\site-packages (from scipy) (1.23.5)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\anaconda3\lib\site-packages)

# %%
#Creamos la primera columna (i)
col_i = pd.DataFrame({'num': range(1,501)})
col_i
# Out:
#      num
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 495  496
# 496  497
# 497  498
# 498  499
# 499  500
#
# [500 rows x 1 columns]

# %%
#Columna 2 (Ui), número aleatorio uniforme entre 0 y 1

ui = [random.uniform(0,1)for i in range(500)]
tabla = pd.DataFrame(col_i)
tabla ['Ui'] = ui 
tabla
# Out:
#      num        Ui  Limite inferior  Limite superior
# 0      1  0.525267             0.00             0.01
# 1      2  0.378012             0.01             0.02
# 2      3  0.561334             0.02             0.03
# 3      4  0.373185             0.03             0.04
# 4      5  0.250275             0.04             0.05
# ..   ...       ...              ...              ...
# 495  496  0.454148             4.95             4.96
# 496  497  0.685522             4.96             4.97
# 497  498  0.793537             4.97             4.98
# 498  499  0.658957             4.98             4.99
# 499  500  0.560540             4.99             5.00
#
# [500 rows x 4 columns]

# %%
#Revisamos que tan uniforme fue el ejercicio anterior ploteandolo

plt.hist(ui)
plt.show()

# %%
#Agregamos columna de limite inferior y superiorior

lim_inf = []
lim_sup = []

for i in range(500):
    inferior = i/100
    superior = (inferior + .01)
    lim_inf.append(inferior)
    lim_sup.append(superior)

limites = pd.DataFrame({'Limite inferior' : lim_inf,
                        'Limite superior' : lim_sup})

limites
# Out:
#      Limite inferior  Limite superior
# 0               0.00             0.01
# 1               0.01             0.02
# 2               0.02             0.03
# 3               0.03             0.04
# 4               0.04             0.05
# ..               ...              ...
# 495             4.95             4.96
# 496             4.96             4.97
# 497             4.97             4.98
# 498             4.98             4.99
# 499             4.99             5.00
#
# [500 rows x 2 columns]

# %%
tabla ['Limite inferior'] = limites['Limite inferior']
tabla ['Limite superior'] = limites['Limite superior']
tabla
# Out:
#      num        Ui  Limite inferior  Limite superior
# 0      1  0.652457             0.00             0.01
# 1      2  0.521279             0.01             0.02
# 2      3  0.904580             0.02             0.03
# 3      4  0.360235             0.03             0.04
# 4      5  0.761479             0.04             0.05
# ..   ...       ...              ...              ...
# 495  496  0.440378             4.95             4.96
# 496  497  0.512812             4.96             4.97
# 497  498  0.788313             4.97             4.98
# 498  499  0.863062             4.98             4.99
# 499  500  0.556857             4.99             5.00
#
# [500 rows x 4 columns]

# %%
#Agregamos una columna para fi, en la que buscamos cuantas veces caen los números aleatorios de Ui 
#en los rangos superiores e inferiores

fi = []

for i in range(500):
    rango = len(tabla[(tabla['Ui'] >= tabla['Limite inferior']) & (tabla['Ui'] <= tabla['Limite superior'])]['Ui'])
    fi.append(rango)

tabla ['fi'] = fi
tabla.head(50)
# Out:
#     num        Ui  Limite inferior  Limite superior  fi
# 0     1  0.652457             0.00             0.01   0
# 1     2  0.521279             0.01             0.02   0
# 2     3  0.904580             0.02             0.03   0
# 3     4  0.360235             0.03             0.04   0
# 4     5  0.761479             0.04             0.05   0
# 5     6  0.867785             0.05             0.06   0
# 6     7  0.596748             0.06             0.07   0
# 7     8  0.360083             0.07             0.08   0
# 8     9  0.208572             0.08             0.09   0
# 9    10  0.562309             0.09             0.10   0
# 10   11  0.532387             0.10             0.11   0
# 11   12  0.376296             0.11             0.12   0
# 12   13  0.850497             0.12             0.13   0
# 13   14  0.378525             0.13             0.14   0
# 14   15  0.737588             0.14             0.15   0
# 15   16  0.342280             0.15             0.16   0
# 16   17  0.741981             0.16             0.17   0
# 17   18  0.654574             0.17             0.18   0
# 18   19  0.951813             0.18             0.19   0
# 19   20  0.296877             0.19             0.20   0
# 20   21  0.789754             0.20             0.21   0
# 21   22  0.586074             0.21             0.22   0
# 22   23  0.547104             0.22             0.23   0
# 23   24  0.917385             0.23             0.24   0
# 24   25  0.160320             0.24             0.25   0
# 25   26  0.175962             0.25             0.26   0
# 26   27  0.901251             0.26             0.27   0
# 27   28  0.595056             0.27             0.28   0
# 28   29  0.881757             0.28             0.29   0
# 29   30  0.495213             0.29             0.30   0
# 30   31  0.125422             0.30             0.31   0
# 31   32  0.043541             0.31             0.32   0
# 32   33  0.391664             0.32             0.33   0
# 33   34  0.129995             0.33             0.34   0
# 34   35  0.996519             0.34             0.35   0
# 35   36  0.455868             0.35             0.36   0
# 36   37  0.988641             0.36             0.37   0
# 37   38  0.638785             0.37             0.38   0
# 38   39  0.588886             0.38             0.39   0
# 39   40  0.811926             0.39             0.40   0
# 40   41  0.452864             0.40             0.41   0
# 41   42  0.854942             0.41             0.42   0
# 42   43  0.552762             0.42             0.43   0
# 43   44  0.094793             0.43             0.44   0
# 44   45  0.841360             0.44             0.45   0
# 45   46  0.732064             0.45             0.46   0
# 46   47  0.931050             0.46             0.47   0
# 47   48  0.815465             0.47             0.48   0
# 48   49  0.203732             0.48             0.49   0
# 49   50  0.239984             0.49             0.50   0

# %%
type(tabla['fi'])
# Out:
# pandas.core.series.Series

# %%
#Ploteamos para ver que la distribución sea uniforme y parece ser que así es
plt.hist(tabla['fi'])
plt.show()

# %%
#Vemos la distribución de todos los números:
tabla.fi.value_counts() #Entonces no es correcto el procedimiento
# Out:
# 0    500
# Name: fi, dtype: int64

# %%
#Provemos con otro metodo para el conteo del fi:
fi2 = []

for i in range(len(tabla)):
    rango = ((tabla['Ui'] >= tabla.loc[i,'Limite inferior']) & (tabla['Ui'] <= tabla.loc[i,'Limite superior'])).sum()
    fi2.append(rango)

tabla['Fi2'] = fi2
tabla
# Out:
#      num        Ui  Limite inferior  Limite superior  fi  Fi2
# 0      1  0.652457             0.00             0.01   0    1
# 1      2  0.521279             0.01             0.02   0    3
# 2      3  0.904580             0.02             0.03   0    4
# 3      4  0.360235             0.03             0.04   0    8
# 4      5  0.761479             0.04             0.05   0    6
# ..   ...       ...              ...              ...  ..  ...
# 495  496  0.440378             4.95             4.96   0    0
# 496  497  0.512812             4.96             4.97   0    0
# 497  498  0.788313             4.97             4.98   0    0
# 498  499  0.863062             4.98             4.99   0    0
# 499  500  0.556857             4.99             5.00   0    0
#
# [500 rows x 6 columns]

# %%
#Parece que esta vez sí funciono, veamoslo en plot:
plt.hist(tabla['Fi2'])
plt.show()

# %% [markdown]
# Ahora sí hay distribución, más no es realmente uniforme, podemos ver que existen muchas variaciones en la distribución, hay cerca de 400 datos que se repiten en el mismo dato

# %%
tabla.Fi2.value_counts().sort_values().head(50)
# Out:
# 1       1
# 11      2
# 12      2
# 9       3
# 10      3
# 7       5
# 8       6
# 2      10
# 6      11
# 4      18
# 5      19
# 3      20
# 0     400
# Name: Fi2, dtype: int64

# %%
#quitamos la columna Fi
tabla = tabla.drop('fi', axis=1) 
tabla
# Out:
#      num        Ui  Limite inferior  Limite superior  Fi2
# 0      1  0.652457             0.00             0.01    1
# 1      2  0.521279             0.01             0.02    3
# 2      3  0.904580             0.02             0.03    4
# 3      4  0.360235             0.03             0.04    8
# 4      5  0.761479             0.04             0.05    6
# ..   ...       ...              ...              ...  ...
# 495  496  0.440378             4.95             4.96    0
# 496  497  0.512812             4.96             4.97    0
# 497  498  0.788313             4.97             4.98    0
# 498  499  0.863062             4.98             4.99    0
# 499  500  0.556857             4.99             5.00    0
#
# [500 rows x 5 columns]

# %%
#Renombramos la columna de Fi2, que fue el segundo intento a "fi":

tabla = tabla.rename(columns={'Fi2': 'fi'})
tabla
# Out:
#      num        Ui  Limite inferior  Limite superior  fi
# 0      1  0.652457             0.00             0.01   1
# 1      2  0.521279             0.01             0.02   3
# 2      3  0.904580             0.02             0.03   4
# 3      4  0.360235             0.03             0.04   8
# 4      5  0.761479             0.04             0.05   6
# ..   ...       ...              ...              ...  ..
# 495  496  0.440378             4.95             4.96   0
# 496  497  0.512812             4.96             4.97   0
# 497  498  0.788313             4.97             4.98   0
# 498  499  0.863062             4.98             4.99   0
# 499  500  0.556857             4.99             5.00   0
#
# [500 rows x 5 columns]

# %%
#Entonces en el ejemplo anterior:
n = 500 #escenarios
k = 100 #intervalos

n_k= n/k
n_k
# Out:
# 5.0

# %% [markdown]
# Recordemos que para l'ecuyer y que sea viable, existe la siguiente condición:
#
# k >= 100
#
# n/k >=5

# %% [markdown]
# n/k= nos dice el promedio que deberían caer por cada sub intervalo, es decir por cada subintervalo deberían caer de manera uniforme 5 por cada uno.
# Esto nos ayuda a ver que tan bueno es el generador y uniforme

# %% [markdown]
# En el caso del presente generador, entonces, nos indicaría que no es bueno al tener más de 400 escenarios cargados en un solo intervalo.

# %% [markdown]
# PARA CALCULAR LA FRECUENCIA (ESPERADA) DE NUESTRO GENERADOR:

# %% [markdown]
# ($f_i$ - n/k)**2

# %%
#Calculamos la frecuencia esperada o desviaciones, lo ideal es que todas fueran 0:

fq_esp = []

for i in range(500):
    fq = ((tabla.loc[i,'fi'] - n_k)**2)
    fq_esp.append(fq)

tabla ['Frecuencia esperada'] = fq_esp
tabla
# Out:
#      num        Ui  Limite inferior  Limite superior  fi  Frecuencia esperada
# 0      1  0.652457             0.00             0.01   1                 16.0
# 1      2  0.521279             0.01             0.02   3                  4.0
# 2      3  0.904580             0.02             0.03   4                  1.0
# 3      4  0.360235             0.03             0.04   8                  9.0
# 4      5  0.761479             0.04             0.05   6                  1.0
# ..   ...       ...              ...              ...  ..                  ...
# 495  496  0.440378             4.95             4.96   0                 25.0
# 496  497  0.512812             4.96             4.97   0                 25.0
# 497  498  0.788313             4.97             4.98   0                 25.0
# 498  499  0.863062             4.98             4.99   0                 25.0
# 499  500  0.556857             4.99             5.00   0                 25.0
#
# [500 rows x 6 columns]

# %%
tabla['Frecuencia esperada'].value_counts().sort_values().head(50)
# Out:
# 36.0      2
# 49.0      2
# 16.0      4
# 9.0      16
# 0.0      19
# 4.0      25
# 1.0      29
# 25.0    403
# Name: Frecuencia esperada, dtype: int64

# %%
tabla['Frecuencia esperada'].mean()
# Out:
# 21.164

# %% [markdown]
# ### Estadistico de prueba

# %%
#sum(tabla['Frecuencia esperada'])*n/k

est_pru = ((tabla['Frecuencia esperada'].sum())/n_k)
est_pru
# Out:
# 2116.4

# %% [markdown]
# ### Grados de libertad

# %%
grad = k-1
grad
# Out:
# 99

# %% [markdown]
# ### Nivel alpha

# %%
alpha = .05

# %%
# Generar valores para la distribución chi cuadrada
x = np.linspace(chi2.ppf(0.01, grad), chi2.ppf(0.99, grad), k)

# %%
# Generar valores para la probabilidad correspondiente a cada valor de chi cuadrada
y = chi2.pdf(x, grad)

# %%
# Graficar la distribución chi cuadrada
plt.plot(x, y, 'r-', lw=2, label='chi2 pdf')
# Agregar línea vertical para el estadístico de prueba
plt.axvline(x= est_pru, color='g', linestyle='--', linewidth=1, label='Estadístico de prueba')
# Agregar zona de rechazo
critico = chi2.ppf(1-alpha, grad)
plt.axvline(x=critico, color='b', linestyle='--', linewidth=1, label='Zona de rechazo')

plt.xlabel('Valor de chi cuadrada')
plt.ylabel('Probabilidad')
plt.title('Distribución chi cuadrada con {} grados de libertad'.format(grad))
plt.legend()

plt.show()

# %% [markdown]
# Ya que la distribución Chi cuadrada no existe debido a la falta de uniformidad en los datos intentaremos con otra libreria para generar nuestros números aleatorios, comenzaremos la tabla desde Ui

# %%
#Intentemos desde el principio, con el generador de numpy:

# %%
#tabla = tabla.drop('Limite inferior', axis = 1)
#tabla = tabla.drop('Limite superior', axis = 1)
tabla
# Out:
#      num
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 495  496
# 496  497
# 497  498
# 498  499
# 499  500
#
# [500 rows x 1 columns]

# %%
n = 500
k = 100
ui = np.sort(np.random.uniform(0, 1, size= n))

# %%
ui
# Out:
# array([0.00322747, 0.0034192 , 0.00481856, 0.00614399, 0.00846992,
#        0.00976666, 0.01124425, 0.0144228 , 0.01585229, 0.01673363,
#        0.01773713, 0.02099555, 0.02236137, 0.0247265 , 0.02777319,
#        0.02947378, 0.02974615, 0.03047686, 0.03198389, 0.03219544,
#        0.03368449, 0.04072966, 0.04175323, 0.04696889, 0.05087788,
#        0.05112689, 0.06246972, 0.06512864, 0.06608951, 0.06695051,
#        0.06765338, 0.06991556, 0.0702104 , 0.07103684, 0.07263701,
#        0.07520588, 0.07568229, 0.07626571, 0.0802241 , 0.08279111,
#        0.08873813, 0.08973469, 0.09105344, 0.09413338, 0.09506631,
#        0.09532374, 0.09828012, 0.09909131, 0.09959777, 0.10231838,
#        0.10293068, 0.10497138, 0.10568544, 0.10707319, 0.10772083,
#        0.11588081, 0.11682755, 0.11793313, 0.1190032 , 0.12084158,
#        0.12241615, 0.12284148, 0.12364181, 0.12465018, 0.12605977,
#        0.12700152, 0.1289672 , 0.12969135, 0.13093428, 0.13395935,
#        0.13666508, 0.13919371, 0.14154365, 0.14176898, 0.14443075,
#        0.14976546, 0.15032011, 0.15176529, 0.15253977, 0.15578941,
#        0.15706092, 0.16182229, 0.16286803, 0.16657578, 0.17078769,
#        0.17227236, 0.17300076, 0.17583896, 0.17605046, 0.1765771 ,
#        0.17720679, 0.17887775, 0.18252651, 0.18363155, 0.18376523,
#        0.18486608, 0.18539737, 0.18768939, 0.19539804, 0.19920499,
#        0.20036668, 0.2017543 , 0.20330674, 0.2057741 , 0.20714984,
#        0.20743503, 0.20854035, 0.20918515, 0.21292908, 0.21350487,
#        0.21381835, 0.21477807, 0.21865228, 0.21925486, 0.2193031 ,
#        0.2196374 , 0.22009657, 0.22075652, 0.22090531, 0.22290493,
#        0.22379321, 0.22525801, 0.22538159, 0.22556625, 0.22647457,
#        0.22772734, 0.22936688, 0.22945326, 0.23088813, 0.23227947,
#        0.23392168, 0.23396712, 0.23412785, 0.23419855, 0.23436727,
#        0.23534152, 0.23712743, 0.2371645 , 0.23718446, 0.24135088,
#        0.24240476, 0.24301784, 0.24574394, 0.24728811, 0.24953879,
#        0.25528454, 0.25552474, 0.26272385, 0.26288579, 0.26519293,
#        0.26546064, 0.26633668, 0.27177139, 0.27185944, 0.27316409,
#        0.27560766, 0.28050699, 0.2818911 , 0.28458039, 0.28695688,
#        0.28726228, 0.29370665, 0.29517735, 0.29639954, 0.29773065,
#        0.29834226, 0.29959407, 0.29997298, 0.30626295, 0.30663655,
#        0.30950979, 0.31013495, 0.31194662, 0.31242619, 0.31407947,
#        0.31706313, 0.31863994, 0.31879757, 0.31958753, 0.32101863,
#        0.32210909, 0.32793635, 0.32834799, 0.33823082, 0.339414  ,
#        0.3441631 , 0.34583882, 0.34721724, 0.34728102, 0.34801143,
#        0.35238007, 0.35331837, 0.3552836 , 0.35532033, 0.35554823,
#        0.35654423, 0.35752486, 0.35838545, 0.36218049, 0.36917916,
#        0.37397516, 0.37873139, 0.37948926, 0.37972706, 0.3802733 ,
#        0.38274309, 0.38329889, 0.38439894, 0.38547655, 0.39011212,
#        0.39234757, 0.39253565, 0.39341325, 0.39574013, 0.40534189,
#        0.40821475, 0.41223819, 0.41320327, 0.41579678, 0.42076952,
#        0.42110791, 0.42204431, 0.42260382, 0.4233275 , 0.42411226,
#        0.42624566, 0.42969858, 0.43047571, 0.43164159, 0.43345437,
#        0.43421016, 0.4426415 , 0.44326727, 0.44813597, 0.44815816,
#        0.44874204, 0.44961307, 0.45842515, 0.46106203, 0.46189681,
#        0.46366672, 0.46380245, 0.46732629, 0.46889309, 0.47153872,
#        0.47159721, 0.47648861, 0.48268015, 0.48323467, 0.4837182 ,
#        0.48441244, 0.48663279, 0.48995734, 0.4908878 , 0.49549528,
#        0.49576468, 0.49712592, 0.49832485, 0.49944781, 0.49995233,
#        0.502551  , 0.50344248, 0.50375463, 0.5040168 , 0.50536271,
#        0.50740469, 0.50814457, 0.51105553, 0.51449804, 0.51538703,
#        0.52053356, 0.5214541 , 0.52152726, 0.52563076, 0.52611795,
#        0.52671523, 0.52960149, 0.53330005, 0.53336138, 0.53442148,
#        0.53528578, 0.53705494, 0.53929174, 0.54286659, 0.54565559,
#        0.54627989, 0.54884561, 0.55485069, 0.55487698, 0.55871433,
#        0.56133806, 0.56350132, 0.56442604, 0.56455225, 0.56520263,
#        0.5663029 , 0.56867347, 0.56926822, 0.56954054, 0.57089857,
#        0.57454238, 0.57565764, 0.57968229, 0.58226979, 0.58282079,
#        0.58536518, 0.58677554, 0.58789473, 0.59206289, 0.59256866,
#        0.59342621, 0.59485521, 0.59575373, 0.59576119, 0.59663541,
#        0.5983291 , 0.60407118, 0.60915069, 0.60965148, 0.61434063,
#        0.61749059, 0.618236  , 0.62209885, 0.62313277, 0.62549477,
#        0.62590816, 0.62926613, 0.63028162, 0.63119645, 0.63135019,
#        0.63226147, 0.63755008, 0.63822543, 0.63901758, 0.64213682,
#        0.64575672, 0.64723088, 0.65195353, 0.65418821, 0.6542516 ,
#        0.65441241, 0.6578359 , 0.6639862 , 0.66681474, 0.67690048,
#        0.67796824, 0.6816022 , 0.68235911, 0.68396255, 0.68431459,
#        0.68753906, 0.68946129, 0.69519276, 0.69625074, 0.6977932 ,
#        0.70602351, 0.71271044, 0.71399911, 0.71555412, 0.71641532,
#        0.71759983, 0.71761629, 0.72008582, 0.72645424, 0.72875044,
#        0.72883609, 0.73049206, 0.73595904, 0.73687463, 0.74035602,
#        0.74194821, 0.74532022, 0.75185265, 0.75191551, 0.7524333 ,
#        0.75531748, 0.75662218, 0.75853936, 0.76363406, 0.76469236,
#        0.76929145, 0.77107587, 0.77232771, 0.77327296, 0.77593981,
#        0.78014204, 0.78026343, 0.78367553, 0.78441422, 0.78627036,
#        0.78791014, 0.78951209, 0.78992369, 0.79127169, 0.79291455,
#        0.79618595, 0.79918522, 0.80123741, 0.80140791, 0.80262409,
#        0.80275199, 0.80509332, 0.80577793, 0.80698352, 0.80765551,
#        0.8127531 , 0.81356462, 0.82402412, 0.82456102, 0.82646897,
#        0.82870298, 0.82960304, 0.83596928, 0.83701803, 0.84024242,
#        0.84616372, 0.84867745, 0.85171317, 0.85305269, 0.8549965 ,
#        0.85678504, 0.86262615, 0.8629138 , 0.86395227, 0.86548445,
#        0.86694116, 0.86731031, 0.87723475, 0.87861209, 0.88105725,
#        0.88202445, 0.88670807, 0.88792199, 0.89004498, 0.89189101,
#        0.89294666, 0.89504188, 0.89574154, 0.89603402, 0.89677426,
#        0.89689792, 0.89743209, 0.90096565, 0.90172461, 0.90253539,
#        0.90441862, 0.9055992 , 0.90579608, 0.90770798, 0.91502925,
#        0.91625175, 0.91758223, 0.92165815, 0.92312339, 0.92491937,
#        0.92513017, 0.92648057, 0.92889468, 0.92935795, 0.9303716 ,
#        0.93040042, 0.93213167, 0.93645793, 0.94096394, 0.94131005,
#        0.94396294, 0.94639641, 0.94742656, 0.94819374, 0.94845405,
#        0.95314913, 0.95389999, 0.95512167, 0.95672973, 0.95738414,
#        0.95757048, 0.95989367, 0.96777028, 0.96801213, 0.9712686 ,
#        0.97229489, 0.97368547, 0.97380928, 0.97457176, 0.975999  ,
#        0.97943413, 0.98067542, 0.98149826, 0.98442187, 0.98468507,
#        0.98683954, 0.98746685, 0.98942392, 0.98996776, 0.99040168,
#        0.99221643, 0.99238397, 0.99506491, 0.99611317, 0.9969369 ])

# %%
plt.hist(ui)
plt.show()

# %% [markdown]
# Con esta librería se ven un poco más distribuidos y uniformes entre 0 y 1

# %%
tabla['ui'] = ui
tabla
# Out:
#      num  fi        ui
# 0      1   0  0.000297
# 1      2   0  0.002127
# 2      3   0  0.005149
# 3      4   0  0.012734
# 4      5   0  0.012860
# ..   ...  ..       ...
# 495  496   0  0.990047
# 496  497   0  0.990637
# 497  498   0  0.990909
# 498  499   0  0.993190
# 499  500   0  0.998628
#
# [500 rows x 3 columns]

# %%
#tabla = tabla.drop('fi', axis=1)
tabla
# Out:
#      num        ui
# 0      1  0.000297
# 1      2  0.002127
# 2      3  0.005149
# 3      4  0.012734
# 4      5  0.012860
# ..   ...       ...
# 495  496  0.990047
# 496  497  0.990637
# 497  498  0.990909
# 498  499  0.993190
# 499  500  0.998628
#
# [500 rows x 2 columns]
